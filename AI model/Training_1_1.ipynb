# %%
import tensorflow.keras as keras
#import keras.preprocessing.image
#import keras.utils
import matplotlib.pyplot as plt
#from keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras.callbacks
#fom keras.models import  model_from_json,Sequential
#fromeras.models import Model as Md
from tensorflow.keras.layers import *
#rom keras.callbacks import EarlyStopping, ModelCheckpoint
#rom keras.optimizers import *
#om attention import Attention
from sklearn.model_selection import train_test_split

#from skimage import color
from sklearn.metrics import accuracy_score
#import cv2b

import pandas as pd
import numpy as np
import os
from tensorflow.keras.layers import Flatten

# %%
"""
import tensorflow.keras as keras
import keras.preprocessing.image
import keras.utils
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
import keras.callbacks
from keras.models import  model_from_json,Sequential
from keras.models import Model as Md
from keras.layers import *
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import *
from attention import Attention

#from skimage import color
#from sklearn.metrics import accuracy_score
#import cv2b

import numpy as np
import os
from keras.layers import Flatten
import pandas as pd
"""
# Out:
# '\nimport tensorflow.keras as keras\nimport keras.preprocessing.image\nimport keras.utils\nimport matplotlib.pyplot as plt\nfrom keras.preprocessing.image import ImageDataGenerator\nimport keras.callbacks\nfrom keras.models import  model_from_json,Sequential\nfrom keras.models import Model as Md\nfrom keras.layers import *\nfrom keras.callbacks import EarlyStopping, ModelCheckpoint\nfrom keras.optimizers import *\nfrom attention import Attention\n\n#from skimage import color\n#from sklearn.metrics import accuracy_score\n#import cv2b\n\nimport numpy as np\nimport os\nfrom keras.layers import Flatten\nimport pandas as pd\n'

# %%
def load_fsdd(spectrograms_path):
    x_train = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, n_frames, 1)
            x_train.append(spectrogram)
    x_train = np.array(x_train)
    x_train = x_train[..., np.newaxis] # -> (3000, 256, 64, 1)
    return x_train

# %%
"""
def load_meta(meta_csv):
    cols = list(pd.read_csv(meta_csv, nrows =1))
    meta = pd.read_csv(meta_csv, usecols =[i for i in cols if i != 'clip_name'])
    y_train = np.array(meta)          
    
    return y_train
"""
# Out:
# "\ndef load_meta(meta_csv):\n    cols = list(pd.read_csv(meta_csv, nrows =1))\n    meta = pd.read_csv(meta_csv, usecols =[i for i in cols if i != 'clip_name'])\n    y_train = np.array(meta)          \n    \n    return y_train\n"

# %%
def load_meta(meta_csv):
    cols = list(pd.read_csv(meta_csv, nrows =1))
    meta = pd.read_csv(meta_csv, usecols =[ "label_consolidated_vocab_Breath",
                                          "label_consolidated_vocab_Laughter",
                                          "label_consolidated_vocab_Music",
                                           "label_consolidated_vocab_Uh",
                                           "label_consolidated_vocab_Um",
                                           "label_consolidated_vocab_Words"]) #i for i in cols if i != 'clip_name'])
    y_train = np.array(meta)          
    
    return y_train

# %%
x_train = load_fsdd('train_demo')

# %%
np.shape(x_train)
# Out:
# (100, 200, 101, 1)

# %%
y_train = load_meta('train.csv')

# %%
np.shape(y_train)
# Out:
# (100, 6)

# %%
images = keras.layers.Input(x_train.shape[1:])
images
# Out:
# <tf.Tensor 'input_1:0' shape=(None, 200, 101, 1) dtype=float32>

# %%
def Model():
    
# ResNet block 1a
    
    images = keras.layers.Input(x_train.shape[1:])
    
    x = keras.layers.Conv2D(filters=16, kernel_size=[3, 3], padding='same')(images)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2a
    block2 = keras.layers.Conv2D(filters=16, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3a
    block3 = keras.layers.Conv2D(filters=16, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    #inio Squeeze and Excitation 1a
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,16))(sq)
    sq = keras.layers.Dense(units=16,activation="relu")(sq)
    sq = keras.layers.Dense(units=16,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=16, kernel_size=[3, 3], padding='same')(images)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)


    #SE-ResNet block 2

    # ResNet block 1b
    x = keras.layers.Conv2D(filters=32, kernel_size=[3, 3], padding='same')(net)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2b
    block2 = keras.layers.Conv2D(filters=32, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3b
    block3 = keras.layers.Conv2D(filters=32, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    #Squeeze and Excitation 1b
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,32))(sq)
    sq = keras.layers.Dense(units=32,activation="relu")(sq)
    sq = keras.layers.Dense(units=32,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=32, kernel_size=[3, 3], padding='same')(net)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)




    #SE-ResNet block 3

    # ResNet block 1c
    x = keras.layers.Conv2D(filters=64, kernel_size=[3, 3], padding='same')(net)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2c
    block2 = keras.layers.Conv2D(filters=64, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3c
    block3 = keras.layers.Conv2D(filters=64, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    #Squeeze and Excitation 1c
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,64))(sq)
    sq = keras.layers.Dense(units=64,activation="relu")(sq)
    sq = keras.layers.Dense(units=64,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=64, kernel_size=[3, 3], padding='same')(net)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)


    #SE-ResNet block 4

    # ResNet block 1d
    x = keras.layers.Conv2D(filters=128, kernel_size=[3, 3], padding='same')(net)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2d
    block2 = keras.layers.Conv2D(filters=128, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3d
    block3 = keras.layers.Conv2D(filters=128, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    # Squeeze and Excitation 1d
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,128))(sq)
    sq = keras.layers.Dense(units=128,activation="relu")(sq)
    sq = keras.layers.Dense(units=128,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=128, kernel_size=[3, 3], padding='same')(net)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)
    
    
    
    #SE-ResNet block 5

    # ResNet block 1e
    x = keras.layers.Conv2D(filters=256, kernel_size=[3, 3], padding='same')(net)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2e
    block2 = keras.layers.Conv2D(filters=256, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3e
    block3 = keras.layers.Conv2D(filters=256, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    # Squeeze and Excitation 1e
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,256))(sq)
    sq = keras.layers.Dense(units=256,activation="relu")(sq)
    sq = keras.layers.Dense(units=256,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=256, kernel_size=[3, 3], padding='same')(net)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)



    
    #SE-ResNet block 6

    # ResNet block 1f
    x = keras.layers.Conv2D(filters=512, kernel_size=[3, 3], padding='same')(net)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2f
    block2 = keras.layers.Conv2D(filters=512, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3f
    block3 = keras.layers.Conv2D(filters=512, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    # Squeeze and Excitation 1f
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,512))(sq)
    sq = keras.layers.Dense(units=512,activation="relu")(sq)
    sq = keras.layers.Dense(units=512,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=512, kernel_size=[3, 3], padding='same')(net)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)
    
    
    #SE-ResNet block 7

    # ResNet block 1g
    x = keras.layers.Conv2D(filters=1024, kernel_size=[3, 3], padding='same')(net)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2g
    block2 = keras.layers.Conv2D(filters=1024, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3g
    block3 = keras.layers.Conv2D(filters=1024, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    # Squeeze and Excitation 1g
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,1024))(sq)
    sq = keras.layers.Dense(units=1024,activation="relu")(sq)
    sq = keras.layers.Dense(units=1024,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=1024, kernel_size=[3, 3], padding='same')(net)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)
    
    
    
    
    #SE-ResNet block 8

    # ResNet block 1h
    x = keras.layers.Conv2D(filters=2048, kernel_size=[3, 3], padding='same')(net)
    block = keras.layers.BatchNormalization()(x)
    block = keras.layers.Activation("relu")(block)

    # ResNet block 2h
    block2 = keras.layers.Conv2D(filters=2048, kernel_size=[3, 3], padding='same')(block)
    block2 = keras.layers.BatchNormalization()(block2)
    block2 = keras.layers.Activation("relu")(block2)

    # ResNet block 3h
    block3 = keras.layers.Conv2D(filters=2048, kernel_size=[3, 3], padding='same')(block2)
    block3 = keras.layers.BatchNormalization()(block3)
    block3 = keras.layers.Activation("relu")(block3)

    # Squeeze and Excitation 1h
    sq = keras.layers.GlobalAveragePooling2D()(block3)
    sq = keras.layers.Reshape((1,1,2048))(sq)
    sq = keras.layers.Dense(units=2048,activation="relu")(sq)
    sq = keras.layers.Dense(units=2048,activation="sigmoid")(sq)
    block = keras.layers.multiply([block3,sq])

    #Res block
    x = keras.layers.Conv2D(filters=2048, kernel_size=[3, 3], padding='same')(net)
    x = keras.layers.BatchNormalization()(x)

    #final Output
    net = keras.layers.add([x,block])
    net = keras.layers.Activation("relu")(net)

    #net = Flatten()(net)
    

    #BLSTM
    #forwards = LSTM(2048,return_sequences=True, activation='sigmoid' )(net)
    #backwards = LSTM(2048,return_sequences=True,activation='sigmoid', go_backwards = True)(net)
    #merged = merge([forwards,backwards],mode='mul')
    #after_dp = Dropout(0.2)(merged)
    
    
    
    #Output layer, Attention Network
    #net = Attention(units=512)(net)
    net = Flatten()(net)
    net = Dropout(0.5)(net) 
    x = Dense(6)(net)
    net = keras.layers.Activation("relu")(x)
    
    model = keras.models.Model(inputs=images,outputs=net)
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    
    return model

# %%
def train(x_trin, y_trin, learning_rate = 0.7, batch_size =int(11) , epochs=int(4)):
    #print(model.summary())
    #checkpointer = keras.callbacks.ModelCheckpoint(filepath = 'cnn_from_scratch_fruits.hdf5', verbose = 1, save_best_only = True)
    #earlystopper = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
    #train_model = Model().fit(x_train, y_train, learning_rate, batch_size, epochs,  callbacks = [checkpointer,earlystopper], shuffle=True)
    train_model = Model().fit(x_trin, y_trin, learning_rate, batch_size, epochs)
    #train_model.load_weights('SE-ResNet_for_disfluency.hdf5')
    return train_model

# %%
Model().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 200, 101, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 101, 16) 160         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 101, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 200, 101, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 200, 101, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 200, 101, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 200, 101, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 200, 101, 16) 2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 200, 101, 16) 64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 200, 101, 16) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 16)           0           activation_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 16)     0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 1, 16)     272         reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 200, 101, 16) 160         input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 16)     272         dense[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 200, 101, 16) 64          conv2d_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 200, 101, 16) 0           activation_2[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 200, 101, 16) 0           batch_normalization_3[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 200, 101, 16) 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 200, 101, 32) 4640        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 200, 101, 32) 128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 200, 101, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 200, 101, 32) 9248        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 200, 101, 32) 128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 200, 101, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 200, 101, 32) 9248        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 200, 101, 32) 128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 200, 101, 32) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 32)           0           activation_6[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 32)     1056        reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 200, 101, 32) 4640        activation_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 32)     1056        dense_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 200, 101, 32) 128         conv2d_7[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 200, 101, 32) 0           activation_6[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 200, 101, 32) 0           batch_normalization_7[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 200, 101, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 200, 101, 64) 18496       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 200, 101, 64) 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 200, 101, 64) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 200, 101, 64) 36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 200, 101, 64) 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 200, 101, 64) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 200, 101, 64) 36928       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 200, 101, 64) 256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 200, 101, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 64)           0           activation_10[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 64)     0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 64)     4160        reshape_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 200, 101, 64) 18496       activation_7[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 64)     4160        dense_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 200, 101, 64) 256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 200, 101, 64) 0           activation_10[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 200, 101, 64) 0           batch_normalization_11[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 200, 101, 64) 0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 200, 101, 128 73856       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 200, 101, 128 512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 200, 101, 128 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 200, 101, 128 147584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 200, 101, 128 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 200, 101, 128 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 200, 101, 128 147584      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 200, 101, 128 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 200, 101, 128 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 128)          0           activation_14[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 128)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 128)    16512       reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 200, 101, 128 73856       activation_11[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 128)    16512       dense_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 200, 101, 128 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 200, 101, 128 0           activation_14[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 200, 101, 128 0           batch_normalization_15[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 200, 101, 128 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 200, 101, 256 295168      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 200, 101, 256 1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 200, 101, 256 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 200, 101, 256 590080      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 200, 101, 256 1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 200, 101, 256 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 200, 101, 256 590080      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 200, 101, 256 1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 200, 101, 256 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 256)          0           activation_18[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 256)    65792       reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 200, 101, 256 295168      activation_15[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 256)    65792       dense_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 200, 101, 256 1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 200, 101, 256 0           activation_18[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 200, 101, 256 0           batch_normalization_19[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 200, 101, 256 0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 200, 101, 512 1180160     activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 200, 101, 512 2048        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 200, 101, 512 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 200, 101, 512 2359808     activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 200, 101, 512 2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 200, 101, 512 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 200, 101, 512 2359808     activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 200, 101, 512 2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 200, 101, 512 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 512)          0           activation_22[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 512)    262656      reshape_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 200, 101, 512 1180160     activation_19[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 512)    262656      dense_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 200, 101, 512 2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 200, 101, 512 0           activation_22[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 200, 101, 512 0           batch_normalization_23[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 200, 101, 512 0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 200, 101, 102 4719616     activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 200, 101, 102 4096        conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 200, 101, 102 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 200, 101, 102 9438208     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 200, 101, 102 4096        conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 200, 101, 102 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 200, 101, 102 9438208     activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 200, 101, 102 4096        conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 200, 101, 102 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 1024)         0           activation_26[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 1024)   0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 1024)   1049600     reshape_6[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 200, 101, 102 4719616     activation_23[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 1024)   1049600     dense_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 200, 101, 102 4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 200, 101, 102 0           activation_26[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 200, 101, 102 0           batch_normalization_27[0][0]
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 200, 101, 102 0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 200, 101, 204 18876416    activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 200, 101, 204 8192        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 200, 101, 204 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 200, 101, 204 37750784    activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 200, 101, 204 8192        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 200, 101, 204 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 200, 101, 204 37750784    activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 200, 101, 204 8192        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 200, 101, 204 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 2048)         0           activation_30[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 2048)   0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 2048)   4196352     reshape_7[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 200, 101, 204 18876416    activation_27[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 2048)   4196352     dense_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 200, 101, 204 8192        conv2d_31[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 200, 101, 204 0           activation_30[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 200, 101, 204 0           batch_normalization_31[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 200, 101, 204 0           add_7[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 41369600)     0           activation_31[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 41369600)     0           flatten[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 6)            248217606   dropout[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 6)            0           dense_16[0][0]
# ==================================================================================================
# Total params: 410,482,630
# Trainable params: 410,449,990
# Non-trainable params: 32,640
# __________________________________________________________________________________________________

# %%
Model().fit(x_train, y_train, batch_size=2, epochs=1)

# %%
Model().load_weights('SE-ResNet_for_disfluency.hdf5')

train_model = model.fit(x_train, y_train, batch_size, epochs,
                      validation_data=(x_val, y_val), callbacks = [checkpointer,earlystopper], shuffle=True)

# %%
y_test_pred = model.predict(x_test)
accuracy_score(np.argmax(y_test_pred,axis=1), np.argmax(y_test,axis=1))
